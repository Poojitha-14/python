# %% [markdown]
# <a href="https://colab.research.google.com/github/Poojitha-14/python/blob/main/setoperations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lang={'java','python','c','c++','sql','c'}
print(lang)
lang.add('ruby')
print(lang)
ui={'html','express js','angular'}
lang.update(ui)
print(lang)l
lang.remove('java')#deleting element
print(lang)
lang.discard('c')#deleting element
print(lang)
# Out:
# {'java', 'c', 'python', 'c++', 'sql'}
# {'ruby', 'java', 'c', 'python', 'c++', 'sql'}
# {'c++', 'python', 'sql', 'angular', 'express js', 'ruby', 'html', 'c', 'java'}
# {'c++', 'python', 'sql', 'angular', 'express js', 'ruby', 'html', 'c'}
# {'c++', 'python', 'sql', 'angular', 'express js', 'ruby', 'html'}
