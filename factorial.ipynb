# %% [markdown]
# <a href="https://colab.research.google.com/github/Poojitha-14/python/blob/main/factorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=int(input("enter a number: "))
fact=1
for i in range(1,num+1):
  fact=fact*i
print("the factorial of",num, " is:",fact)
# Out:
# enter a number: 5
# the factorial of 5  is: 120
