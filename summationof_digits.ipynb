# %% [markdown]
# <a href="https://colab.research.google.com/github/Poojitha-14/python/blob/main/summationof_digits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=int(input("enter a number: "))
count=0
rem=0
while(num!=0):
  rem=num%10
  count+=1
  num=num//10
print(f"count of digits is {count}")
# Out:
# enter a number: 2878
# count of digits is 4
