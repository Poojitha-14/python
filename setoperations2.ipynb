# %% [markdown]
# <a href="https://colab.research.google.com/github/Poojitha-14/python/blob/main/setoperations2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
set1={'tom & jerry','oggy & the cockroaches','shinchan','doreamon','motu patlu'}
set2={'oggy & the cockroaches','little krishna','shinchan','ninja hatori'}
print(set1.intersection(set2))
print(set1.union(set2))
print(set1.difference(set2))
print(set2.difference(set1))
print(set1.issubset(set2))
print(set2.issubset(set1))
# Out:
# {'shinchan', 'oggy & the cockroaches'}
# {'ninja hatori', 'shinchan', 'tom & jerry', 'motu patlu', 'oggy & the cockroaches', 'little krishna', 'doreamon'}
# {'motu patlu', 'tom & jerry', 'doreamon'}
# {'ninja hatori', 'little krishna'}
# False
# False
