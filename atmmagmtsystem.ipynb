# %% [markdown]
# <a href="https://colab.research.google.com/github/Poojitha-14/python/blob/main/atmmagmtsystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pin=int(input("enter your pin: "))
acc_bal=0
if pin==1234:
  print("welcome to the bank")
#deposit,withdrawal,balance inquiry and exit
  while True:
   print("1.deposit")
   print("2.withdrawal")
   print("3.balance enquiry")
   print("4.exit")

   choice=int(input("enter your choice"))
   print("\n")
   if(choice==1):
     amount=int(input("enter the amount to deposit : "))
     acc_bal=acc_bal+amount
     print(f"dear customer your account xxxxxx1234 is credited with {amount}")
   elif(choice==2):
     amount=int(input("enter the amount to withdraw : "))
     if (amount<acc_bal):
       print(f"dear customer your account xxxxxx1234 is debited with {amount}")
       acc_bal=acc_bal-amount
     else:
       print("insufficient balance")
   elif(choice==3):
       print(f"dear customer your account xxxxxx1234 has{acc_bal} .")
   else:
       print(f"thank you....")
       break
else:
  print("you entered wrong pin.")
# Out:
# enter your pin: 1234
# welcome to the bank
# 1.deposit
# 2.withdrawal
# 3.balance enquiry
# 4.exit
# enter your choice1
#
#
# enter the amount to deposit : 2000
# dear customer your account xxxxxx1234 is credited with 2000
# 1.deposit
# 2.withdrawal
# 3.balance enquiry
# 4.exit
# enter your choice2
#
#
# enter the amount to withdraw : 1000
# dear customer your account xxxxxx1234 is debited with 1000
# 1.deposit
# 2.withdrawal
# 3.balance enquiry
# 4.exit
# enter your choice3
#
#
# dear customer your account xxxxxx1234 has1000 .
# 1.deposit
# 2.withdrawal
# 3.balance enquiry
# 4.exit
# enter your choice4
#
#
# thank you....
